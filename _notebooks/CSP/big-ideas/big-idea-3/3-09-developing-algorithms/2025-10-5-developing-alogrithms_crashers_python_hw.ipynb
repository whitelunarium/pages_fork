# %% [raw]
# ---
# layout: post
# title: Crashers - 3.9 Developing Algorithms Python Hacks
# categories: [Python]
# tags: [python, algorithms, boolean, conditionals, beginner]
# description: Learn how to develop algorithms through the Peppa Pig Maze game
# permalink: /python/developing-algorithms/crashers-hw
# ---

# %% [markdown]
# # 🐷 Peppa's Algorithm Adventures - Python Hacks
#
# Welcome to Peppa's Python algorithm challenges! Complete these three hacks to master algorithm development with interactive Python examples.

# %% [markdown]
# ## Hack 1: Mummy Pig's Garden Height Checker 🌻
#
# Help Mummy Pig check if her sunflowers are tall enough using Boolean expressions!
#
# **Your task:** Complete the missing Boolean conditions to validate sunflower heights.

# %%
# Mummy Pig's garden height algorithms (like the lesson examples!)

def check_sunflower_height(current_height, min_height):
    """Check if sunflower is tall enough"""
    # TODO: Complete the Boolean condition
    is_tall_enough = current_height _____ min_height  # Replace _____ with comparison operator
    
    if is_tall_enough:
        print(f"✅ Sunflower {current_height}cm is tall enough! (Min: {min_height}cm)")
    else:
        print(f"❌ Sunflower {current_height}cm needs to grow more! (Min: {min_height}cm)")
    
    return is_tall_enough

def compare_flower_heights(height1, height2):
    """Compare two flower heights"""
    # TODO: Complete the Boolean expression (like lesson example)
    taller_flower = "Flower 1" if height1 _____ height2 else "Flower 2"  # Replace _____ with comparison
    
    print(f"🌻 {taller_flower} is taller! ({height1}cm vs {height2}cm)")
    return taller_flower

def mummy_pig_gardening():
    """Help Mummy Pig check her garden"""
    print("🌱 Mummy Pig's Garden Algorithm")
    
    sunflower_height = 45
    required_height = 40
    
    # TODO: Complete the Boolean condition
    ready_for_show = sunflower_height _____ required_height  # Fill in comparison operator
    
    if ready_for_show:
        print("🐷 Mummy Pig says: 'Perfect! Ready for the garden show!'")
    else:
        print("🐷 Mummy Pig says: 'Need to wait a bit longer!'")

# Test the algorithms (like the lesson does)
print("=== Testing Height Algorithms ===")
check_sunflower_height(35, 40)
check_sunflower_height(50, 40)

print("\n=== Comparing Flower Heights ===")
compare_flower_heights(42, 38)

print("\n=== Mummy Pig's Garden Check ===")
mummy_pig_gardening()

# %% [markdown]
# ## Hack 2: Rebecca Rabbit's Carrot Counting Game 🥕
#
# Help Rebecca Rabbit create a simple counting game using conditional statements!
#
# **Your task:** Complete the `if/else` conditions for Rebecca's interactive game.

# %%
# Rebecca Rabbit's carrot counting algorithm (similar to lesson's decision examples!)

def carrot_sharing_checker():
    """Check if there are enough carrots to share"""
    print("🥕 Rebecca's Carrot Sharing Checker")
    
    total_carrots = 12
    num_friends = 4
    min_per_friend = 2
    
    # TODO: Complete the Boolean conditions
    enough_carrots = total_carrots _____ (num_friends * min_per_friend)  # Fill in comparison operator
    fair_share = (total_carrots // num_friends) _____ min_per_friend     # Fill in comparison operator
    
    # TODO: Complete the logical condition using AND
    can_share_fairly = enough_carrots _____ fair_share  # Fill in logical operator (and/or)
    
    if can_share_fairly:
        print(f"✅ Great! {total_carrots} carrots can be shared among {num_friends} friends!")
    else:
        print(f"❌ Sorry, only {total_carrots} carrots for {num_friends} friends isn't enough!")
    
    return can_share_fairly

def rebecca_game_chooser(num_carrots, is_sunny):
    """Choose what game to play based on conditions"""
    print("🐰 Rebecca's Game Choice Algorithm")
    print(f"Carrots available: {num_carrots}, Sunny day: {is_sunny}")
    
    # TODO: Complete the if/else statements
    if num_carrots >= 10:
        if is_sunny:
            activity = "Carrot treasure hunt outside! 🌞"
        else:
            activity = _____  # Fill in indoor activity with many carrots
    elif num_carrots >= 5:
        activity = _____  # Fill in medium carrot activity
    else:
        activity = _____  # Fill in low carrot activity
    
    print(f"🎯 Rebecca chooses: {activity}")
    return activity

def interactive_carrot_game():
    """Interactive carrot counting test"""
    print("\n🎮 Interactive Carrot Game Test")
    
    # Simulate random scenarios
    import random
    random_carrots = random.randint(3, 15)
    is_sunny = random.choice([True, False])
    
    print(f"🎲 Random scenario: {random_carrots} carrots, sunny: {is_sunny}")
    
    game_choice = rebecca_game_chooser(random_carrots, is_sunny)
    can_share = carrot_sharing_checker()
    
    if can_share:
        print(f"🎉 Rebecca and friends are playing: {game_choice}")
    else:
        print("😢 Rebecca needs to find more carrots first!")

# Run the carrot algorithms
carrot_sharing_checker()
rebecca_game_chooser(8, True)
rebecca_game_chooser(3, False)
interactive_carrot_game()

# %% [markdown]
# ## Hack 3: Grandpa Pig's Train Route Planner 🚂
#
# Help Grandpa Pig plan safe train routes using boundary checking!
#
# **Your task:** Complete the Boolean conditions to control the train's movement safely.

# %%
# Grandpa Pig's train route algorithm (similar to lesson's maze example)

def grandpa_train_route_planner():
    """Plan safe train routes using boundary checking"""
    print("🚂 Grandpa Pig's Train Route Algorithm")
    
    # Current train station position
    train_station = 3
    
    # Railway track limits (like the lesson's maze boundaries)  
    first_station = 1
    last_station = 6
    
    print(f"🚂 Train is at station {train_station}")
    print(f"🛤️ Railway runs from station {first_station} to {last_station}")
    
    # Test different destinations
    print("\n--- Testing Train Routes ---")
    
    # Try going to station 5
    destination_a = 5
    # TODO: Complete the Boolean condition (like lesson's canPeppaMove function)
    can_reach_a = destination_a _____ last_station  # Replace _____ with comparison operator
    
    print(f"Route to station {destination_a}: {'✅ Safe route' if can_reach_a else '❌ Beyond tracks'}")
    
    # Try going to station 0
    destination_b = 0
    # TODO: Complete the Boolean condition
    can_reach_b = destination_b _____ first_station  # Replace _____ with comparison operator
    
    print(f"Route to station {destination_b}: {'✅ Safe route' if can_reach_b else '❌ Before first station'}")
    
    # Try going to station 4
    destination_c = 4
    # TODO: Complete the Boolean condition using range checking
    can_reach_c = (first_station _____ destination_c) and (destination_c _____ last_station)  # Fill in operators
    
    print(f"Route to station {destination_c}: {'✅ Safe route' if can_reach_c else '❌ Out of range'}")

def interactive_train_planner():
    """Let user test train route planning"""
    print("\n🎯 Interactive Train Route Test")
    
    current_station = 2
    
    # Simulate different destinations
    import random
    destinations = [0, 1, 3, 6, 7, 8]
    random_dest = random.choice(destinations)
    
    print(f"🎲 Grandpa wants to go from station {current_station} to station {random_dest}")
    
    # TODO: Complete the Boolean conditions for valid railway range
    valid_destination = (_____ <= random_dest <= _____)  # Fill in the station range (1 to 6)
    within_range = abs(random_dest - current_station) <= 3  # Max 3 stations per trip
    
    can_make_trip = valid_destination and within_range
    
    if can_make_trip:
        print(f"✅ Grandpa Pig successfully planned route to station {random_dest}!")
    else:
        if not valid_destination:
            print(f"❌ Station {random_dest} doesn't exist on this railway!")
        else:
            print(f"❌ Station {random_dest} is too far for one trip!")

# Run Grandpa's train algorithms
grandpa_train_route_planner()
interactive_train_planner()

# %% [markdown]
# ## 📝 What You Should Complete
#
# **After finishing the lesson, you should be able to:**
#
# 1. **Hack 1**: Fill in the Boolean comparison operators (`>=`, `>`, `<=`) to make Mummy Pig's height checker work
# 2. **Hack 2**: Complete the `if/elif/else` statements and fill in missing activity choices for Rebecca's carrot game
# 3. **Hack 3**: Fill in the boundary conditions for Grandpa Pig's train route planner
#
# **These exercises use the SAME Python concepts from the lesson:**
# - Boolean expressions with comparison operators
# - `if/elif/else` conditional statements
# - Logical operators (`and`, `or`)
# - Simple variable comparisons
# - Print statements for output
#
# **Estimated time: 5 minutes** ⏰
#
# **What makes this appropriate for the lesson:**
# - Uses identical Python syntax patterns shown in class
# - Same Boolean logic concepts (comparison operators)
# - Same conditional statement structure (`if/else`)
# - Same variable types and operations
# - Peppa Pig universe theming matches the lesson examples
#
# **Expected Learning Outcomes:**
# - Practice writing Boolean conditions in Python
# - Understand boundary checking logic
# - Apply conditional statements to real scenarios
# - Debug simple logical expressions
# - Use print() for output and feedback
#
# **Interactive Features:**
# - **Visual feedback** with emojis and symbols
# - **Random scenarios** for testing different conditions
# - **Step-by-step explanations** of algorithm decisions
# - **Real-time validation** showing why choices are made
