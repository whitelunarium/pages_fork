# %% [markdown]
# ---
# layout: post
# title: Sprint 2 - Algorithmic Efficiency Homework(Javascript)
# description: Homework for the Algorithmic Effiency in Javascript
# toc: true
# breadcrumbs: True
# authors: Akhil K, Shayan B
# permalink: /csp/big-idea-3/AlgEffJS/p3/Homework/TheSprinters
# ---

# %% [markdown]
# <style>
# /* ===== ULTRAVIOLET GLOBAL BACKGROUND ===== */
# body {
#   background: radial-gradient(circle at top left, #140520, #0b0418 45%, #03010b 90%);
#   color: #eae4ff;
#   font-family: "Segoe UI", Roboto, sans-serif;
#   margin: 0;
#   padding: 50px 10px;
#   text-align: center;
# }
#
# /* ===== GLOW & PULSE EFFECTS ===== */
# @keyframes glowPulse {
#   0%, 100% {
#     text-shadow: 0 0 10px rgba(192, 132, 252, 0.9),
#                  0 0 25px rgba(139, 92, 246, 0.7);
#   }
#   50% {
#     text-shadow: 0 0 20px rgba(192, 132, 252, 1),
#                  0 0 40px rgba(139, 92, 246, 0.9);
#   }
# }
#
# @keyframes boxPulse {
#   0%, 100% {
#     box-shadow:
#       0 0 25px rgba(192, 132, 252, 0.4),
#       inset 0 0 15px rgba(192, 132, 252, 0.15);
#   }
#   50% {
#     box-shadow:
#       0 0 40px rgba(192, 132, 252, 0.7),
#       inset 0 0 25px rgba(192, 132, 252, 0.3);
#   }
# }
#
# /* ===== ACTIVITY CARD ===== */
# .activity-card {
#   background: rgba(20, 10, 35, 0.92);
#   border: 2px solid rgba(192, 132, 252, 0.45);
#   border-radius: 16px;
#   max-width: 950px;
#   margin: 0 auto 60px;
#   padding: 40px 55px;
#   text-align: left;
#   animation: boxPulse 4s infinite ease-in-out;
# }
#
# /* ===== HEADINGS ===== */
# .activity-card h2 {
#   font-size: 2em;
#   font-weight: 800;
#   background: linear-gradient(90deg, #c084fc, #a78bfa, #ddd6fe);
#   -webkit-background-clip: text;
#   -webkit-text-fill-color: transparent;
#   text-shadow:
#     0 0 15px rgba(192, 132, 252, 0.9),
#     0 0 30px rgba(139, 92, 246, 0.8);
#   animation: glowPulse 3s infinite ease-in-out;
#   text-align: center;
#   margin-bottom: 25px;
# }
#
# .activity-card h3 {
#   color: #d9c3ff;
#   font-size: 1.4em;
#   font-weight: 600;
#   margin-top: 25px;
# }
#
# /* ===== PARAGRAPHS & LISTS ===== */
# .activity-card p,
# .activity-card li {
#   color: #e8dcff;
#   font-size: 1.05em;
#   line-height: 1.7;
#   letter-spacing: 0.3px;
# }
#
# .activity-card ul {
#   margin-left: 25px;
# }
#
# .activity-card code {
#   background: rgba(30, 20, 50, 0.85);
#   color: #c084fc;
#   padding: 3px 6px;
#   border-radius: 5px;
#   font-size: 1.05em;
#   font-family: "Courier New", monospace;
# }
#
# /* ===== CODE EXAMPLE BOX ===== */
# .code-box {
#   background: #0a0a0a;
#   border: 2px solid #c084fc;
#   border-radius: 10px;
#   padding: 20px 25px;
#   margin-top: 20px;
#   font-family: "Courier New", monospace;
#   color: #ddd6fe;
#   box-shadow: 0 0 15px rgba(192, 132, 252, 0.5);
#   white-space: pre-wrap;
#   font-size: 1em;
# }
# </style>
#
# <div class="activity-card">
#   <h2>JS Algorithmic Efficiency Activity: Sum of Even Numbers</h2>
#
#   <h3>🎯 Goal</h3>
#   <p>Write a function that takes an array of numbers and calculates the <b>sum of all even numbers</b>.
#   After completing the function, analyze the <b>time and memory complexity</b> of your solution.</p>
#
#   <h3>🧩 Instructions</h3>
#   <ul>
#     <li>Complete the function <code>sumEvenNumbers(arr)</code> in the next code cell.</li>
#     <li>Test it with arrays of different sizes.</li>
#     <li>Think about:</li>
#     <ul>
#       <li><b>Time Complexity:</b> How long it takes to compute as the array grows.</li>
#       <li><b>Memory Complexity:</b> How much extra memory your algorithm uses.</li>
#     </ul>
#     <li>Optional: Try to optimize memory usage if possible (e.g., avoid creating extra arrays).</li>
#   </ul>
#
#   <h3>💡 Example</h3>
#   <div class="code-box">
# // Input: [1,2,3,4,5]
# // Output: 6 (because 2 + 4 = 6)
#   </div>
# </div>
#
# <style>
# /* === SAFE RESET CSS (for use inside Markdown/HTML blocks) === */
#
# /* Left-align all text content inside this scope */
# * {
#   text-align: left !important;
# }
#
# /* Code blocks (fenced or <pre><code>) */
# pre {
#   text-align: left !important;
#   margin-left: 0 !important;
#   margin-right: auto !important;
#   display: block !important;
#   white-space: pre !important;
#   overflow-x: auto;
#   border-radius: 6px;
# }
#
# /* Inline code snippets (like <code>n</code>) */
# code {
#   text-align: left !important;
#   display: inline !important;
#   margin: 0 2px !important;
#   white-space: pre !important;
#   vertical-align: baseline;
# }
# </style>

# %%
// Starter Code to Build Off of:

// Task: Complete this function
function sumEvenNumbers(arr) {
  // Your code here
}

// Test your function
const testArray = [1, 2, 3, 4, 5];
console.log("Sum of even numbers:", sumEvenNumbers(testArray));

// Optional: test with larger arrays
const largeArray = Array.from({length: 10}, (_, i) => i + 1);
console.log("Sum of even numbers in large array:", sumEvenNumbers(largeArray));
