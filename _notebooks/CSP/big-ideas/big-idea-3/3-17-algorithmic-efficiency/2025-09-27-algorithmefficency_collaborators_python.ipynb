# %% [raw]
# ---
# layout: post
# title: Algorithm Efficiency Homework
# description: Quick practice with Algorithm Efficiency
# permalink: csp/python/algorithmefficency/collaborators/homework
# authors: Vivian Z, Virgnia Z
# ---

# %% [markdown]
# <style>
# /* ⚙️ Algorithmic Efficiency Theme */
# .algo-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   line-height: 1.7em;
#   border: 1px solid rgba(0, 255, 170, 0.4);
# }
#
# .algo-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 16px;
# }
#
# .algo-box p {
#   font-weight: 500;
#   margin-bottom: 8px;
#   margin-top: 12px;
# }
#
# .algo-box label {
#   display: inline-block;
#   margin: 4px 12px 10px 0;
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   padding: 6px 14px;
#   border-radius: 8px;
#   transition: all 0.2s ease;
#   cursor: pointer;
# }
#
# .algo-box label:hover {
#   background: rgba(0,255,204,0.2);
#   box-shadow: 0 0 8px rgba(0,255,204,0.5);
# }
#
# .algo-box input[type="radio"] {
#   accent-color: #00ffcc;
#   margin-right: 6px;
#   transform: scale(1.2);
# }
# </style>
#
# <div class="algo-box">
#   <h2>⚙️ 1️⃣ Decision vs Optimization</h2>
#
#   <p><b>A.</b> Is there a path from your house to school?</p>
#   <label><input type="radio" name="p1a" value="A"> A</label>
#   <label><input type="radio" name="p1a" value="B"> B</label>
#
#   <p><b>B.</b> What is the shortest path from your house to school?</p>
#   <label><input type="radio" name="p1b" value="A"> A</label>
#   <label><input type="radio" name="p1b" value="B"> B</label>
#
#   <p><b>C.</b> Can all classes fit into a weekly schedule without overlap?</p>
#   <label><input type="radio" name="p1c" value="A"> A</label>
#   <label><input type="radio" name="p1c" value="B"> B</label>
#
#   <p><b>D.</b> Minimize total travel time for deliveries to 10 cities.</p>
#   <label><input type="radio" name="p1d" value="A"> A</label>
#   <label><input type="radio" name="p1d" value="B"> B</label>
# </div>

# %%
Type A or B for each question below
A.
B.
C.
D.

# %% [markdown]
# <style>
# /* 📊 Algorithm Efficiency Table Styling */
# .algo-table-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   line-height: 1.7em;
#   border: 1px solid rgba(0, 255, 170, 0.4);
# }
#
# .algo-table-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# /* 🧮 Table Styling */
# .algo-table {
#   width: 100%;
#   border-collapse: collapse;
#   border-radius: 10px;
#   overflow: hidden;
#   box-shadow: 0 0 10px rgba(0,255,204,0.15);
# }
#
# .algo-table th, .algo-table td {
#   padding: 10px 14px;
#   text-align: center;
# }
#
# .algo-table th {
#   background: rgba(0,255,204,0.1);
#   color: #00ffcc;
#   font-weight: 600;
#   border-bottom: 2px solid rgba(0,255,204,0.3);
#   text-shadow: 0 0 6px rgba(0,255,204,0.7);
# }
#
# .algo-table tr:nth-child(even) {
#   background: rgba(255,255,255,0.03);
# }
#
# .algo-table tr:hover {
#   background: rgba(0,255,204,0.08);
#   transition: background 0.2s ease-in-out;
# }
#
# .algo-table td {
#   border-bottom: 1px solid rgba(255,255,255,0.08);
# }
# </style>
#
# <div class="algo-table-box">
#   <h2>📊 2️⃣ Algorithm Efficiency Table</h2>
#
#   <table class="algo-table">
#     <thead>
#       <tr>
#         <th>Input Size (n)</th>
#         <th>Algorithm X Steps</th>
#         <th>Algorithm Y Steps</th>
#         <th>Algorithm Z Steps</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td>1</td><td>3</td><td>2</td><td>1</td></tr>
#       <tr><td>2</td><td>6</td><td>4</td><td>2</td></tr>
#       <tr><td>3</td><td>9</td><td>8</td><td>6</td></tr>
#       <tr><td>4</td><td>12</td><td>16</td><td>24</td></tr>
#       <tr><td>5</td><td>15</td><td>32</td><td>120</td></tr>
#     </tbody>
#   </table>
# </div>

# %%
Type the growth types for each algorithim below:

Algorithm X:
Algorithm Y:
Algorithm Z: 

Which is most reasonable for large n?

# %% [markdown]
# <style>
# /* ⚡ Algorithm A Styling (3ⁿ Growth) */
# .algoA-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #101018);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algoA-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# .algoA-table {
#   width: 100%;
#   border-collapse: collapse;
#   border-radius: 10px;
#   overflow: hidden;
#   box-shadow: 0 0 10px rgba(0,255,204,0.15);
# }
#
# .algoA-table th, .algoA-table td {
#   padding: 10px 14px;
#   text-align: center;
# }
#
# .algoA-table th {
#   background: rgba(0,255,204,0.1);
#   color: #00ffcc;
#   font-weight: 600;
#   border-bottom: 2px solid rgba(0,255,204,0.3);
#   text-shadow: 0 0 6px rgba(0,255,204,0.7);
# }
#
# .algoA-table tr:nth-child(even) {
#   background: rgba(255,255,255,0.03);
# }
#
# .algoA-table td {
#   border-bottom: 1px solid rgba(255,255,255,0.08);
# }
#
# /* Input fields for student interaction */
# .algoA-table input[type="text"] {
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   color: #00ffcc;
#   text-align: center;
#   border-radius: 6px;
#   width: 70px;
#   padding: 4px 6px;
#   font-weight: bold;
#   transition: all 0.2s ease;
# }
#
# .algoA-table input[type="text"]:focus {
#   outline: none;
#   background: rgba(0,255,204,0.15);
#   box-shadow: 0 0 8px rgba(0,255,204,0.7);
# }
# </style>
#
# <div class="algoA-box">
#   <h2>⚡ 3️⃣ Algorithm A (grows by 3ⁿ)</h2>
#
#   <table class="algoA-table">
#     <thead>
#       <tr>
#         <th>Input Size (n)</th>
#         <th>Steps</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td>1</td><td>3</td></tr>
#       <tr><td>2</td><td><input type="text" placeholder="?" /></td></tr>
#       <tr><td>3</td><td><input type="text" placeholder="?" /></td></tr>
#       <tr><td>4</td><td><input type="text" placeholder="?" /></td></tr>
#       <tr><td>5</td><td><input type="text" placeholder="?" /></td></tr>
#     </tbody>
#   </table>
# </div>

# %%
Type the following steps that belong in the blank boxes below: 



What is the efficency type? 


Is this algorithm reasonable for large input sizes? Type yes or no.

# %% [markdown]
# <style>
# /* 🧮 Counting Steps Section */
# .algo-steps-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algo-steps-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# .algo-steps-box p {
#   font-weight: 500;
#   margin-top: 20px;
#   margin-bottom: 10px;
# }
#
# /* 🔘 Radio label styling */
# .algo-steps-box label {
#   display: inline-block;
#   margin: 6px 12px 10px 0;
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   padding: 6px 14px;
#   border-radius: 8px;
#   transition: all 0.2s ease;
#   cursor: pointer;
# }
#
# .algo-steps-box label:hover {
#   background: rgba(0,255,204,0.2);
#   box-shadow: 0 0 8px rgba(0,255,204,0.5);
# }
#
# .algo-steps-box input[type="radio"] {
#   accent-color: #00ffcc;
#   margin-right: 6px;
#   transform: scale(1.2);
# }
# </style>
#
# <div class="algo-steps-box">
#   <h2>🧮 4️⃣ Counting Steps</h2>
#   <p>Compares every pair of items in a list of size <code>n</code>.</p>
#
#   <p><b>1)</b> Steps for n = 4:</p>
#   <label><input type="radio" name="p4-1" value="A"> A. 4</label>
#   <label><input type="radio" name="p4-1" value="B"> B. 8</label>
#   <label><input type="radio" name="p4-1" value="C"> C. 16</label>
#   <label><input type="radio" name="p4-1" value="D"> D. 24</label>
#
#   <p><b>2)</b> Efficiency type:</p>
#   <label><input type="radio" name="p4-2" value="A"> A. O(n)</label>
#   <label><input type="radio" name="p4-2" value="B"> B. O(n²)</label>
#   <label><input type="radio" name="p4-2" value="C"> C. O(2ⁿ)</label>
#   <label><input type="radio" name="p4-2" value="D"> D. O(n!)</label>
#
#   <p><b>3)</b> Reasonable for very large lists?</p>
#   <label><input type="radio" name="p4-3" value="A"> A. Yes</label>
#   <label><input type="radio" name="p4-3" value="B"> B. No</label>
# </div>

# %%
Types the letter corresponding to the correct answer for each question below:

1.

2.

3.

# %% [markdown]
# <style>
# /* 💡 Heuristic Scenario Styling */
# .algo-heuristic-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0f1117);
#   color: #e9ecf3;
#   padding: 28px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algo-heuristic-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 16px;
#   font-weight: 600;
# }
#
# .algo-heuristic-box p strong {
#   color: #00ffcc;
# }
#
# .algo-heuristic-box textarea {
#   width: 100%;
#   min-height: 80px;
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   border-radius: 8px;
#   color: #00ffcc;
#   padding: 10px;
#   margin-top: 8px;
#   margin-bottom: 18px;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   font-size: 0.95em;
#   resize: vertical;
#   transition: all 0.2s ease;
# }
#
# .algo-heuristic-box textarea:focus {
#   background: rgba(0,255,204,0.15);
#   box-shadow: 0 0 10px rgba(0,255,204,0.6);
#   outline: none;
# }
# </style>
#
# <div class="algo-heuristic-box">
#   <h2>💡 5️⃣ Heuristic Scenario</h2>
#
#   <p><strong>Scenario:</strong> A city wants to design bus routes covering all neighborhoods.
#   There are hundreds of possible routes, and finding the perfect shortest set is too complex.</p>
#
#   <p><b>1)</b> Explain one heuristic approach the city could use:</p>
#   <textarea placeholder="Example: Start with main roads, then expand outward until every area is connected..."></textarea>
#
#   <p><b>2)</b> Why might this heuristic not give the optimal solution?</p>
#   <textarea placeholder="Example: It might miss a shorter overall route or create overlap between paths..."></textarea>
# </div>

# %%
Type your free response to the questions below:

1.

2.

# %% [markdown]
# <style>
# /* ⚙️ Algorithm B Styling */
# .algoB-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algoB-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# .algoB-table {
#   width: 100%;
#   border-collapse: collapse;
#   border-radius: 10px;
#   overflow: hidden;
#   box-shadow: 0 0 10px rgba(0,255,204,0.15);
#   margin-bottom: 20px;
# }
#
# .algoB-table th, .algoB-table td {
#   padding: 10px 14px;
#   text-align: center;
# }
#
# .algoB-table th {
#   background: rgba(0,255,204,0.1);
#   color: #00ffcc;
#   font-weight: 600;
#   border-bottom: 2px solid rgba(0,255,204,0.3);
#   text-shadow: 0 0 6px rgba(0,255,204,0.7);
# }
#
# .algoB-table tr:nth-child(even) {
#   background: rgba(255,255,255,0.03);
# }
#
# .algoB-table td {
#   border-bottom: 1px solid rgba(255,255,255,0.08);
# }
#
# .algoB-table td input[type="text"] {
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   color: #00ffcc;
#   text-align: center;
#   border-radius: 6px;
#   width: 70px;
#   padding: 4px 6px;
#   font-weight: bold;
#   transition: all 0.2s ease;
# }
#
# .algoB-table td input[type="text"]:focus {
#   background: rgba(0,255,204,0.15);
#   box-shadow: 0 0 8px rgba(0,255,204,0.7);
#   outline: none;
# }
#
# /* Radio label styling */
# .algoB-box label {
#   display: inline-block;
#   margin: 6px 12px 8px 0;
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   padding: 6px 14px;
#   border-radius: 8px;
#   transition: all 0.2s ease;
#   cursor: pointer;
# }
#
# .algoB-box label:hover {
#   background: rgba(0,255,204,0.2);
#   box-shadow: 0 0 8px rgba(0,255,204,0.5);
# }
#
# .algoB-box input[type="radio"] {
#   accent-color: #00ffcc;
#   margin-right: 6px;
#   transform: scale(1.2);
# }
# </style>
#
# <div class="algoB-box">
#   <h2>⚙️ 6️⃣ Algorithm B</h2>
#
#   <table class="algoB-table">
#     <thead>
#       <tr>
#         <th>Input Size (n)</th>
#         <th>Steps</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td>1</td><td>2</td></tr>
#       <tr><td>2</td><td>4</td></tr>
#       <tr><td>3</td><td>8</td></tr>
#       <tr><td>4</td><td><input type="text" placeholder="?" /></td></tr>
#       <tr><td>5</td><td><input type="text" placeholder="?" /></td></tr>
#     </tbody>
#   </table>
#
#   <p><b>Efficiency type:</b></p>
#   <label><input type="radio" name="bType"> A. Linear</label>
#   <label><input type="radio" name="bType"> B. Quadratic</label>
#   <label><input type="radio" name="bType"> C. Exponential</label>
#   <label><input type="radio" name="bType"> D. Factorial</label>
#
#   <p><b>Reasonable for large n?</b></p>
#   <label><input type="radio" name="bReasonable"> A. Yes</label>
#   <label><input type="radio" name="bReasonable"> B. No</label>
# </div>

# %%
Type the letter corresponding to the correct answer below:

Efficency type:

Reasonable for large n?

# %% [markdown]
# <style>
# /* 🧭 TSP Heuristic Styling */
# .algo-tsp-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algo-tsp-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# .algo-tsp-box p {
#   margin-bottom: 10px;
#   font-weight: 500;
# }
#
# /* Radio option containers */
# .algo-tsp-box label {
#   display: block;
#   background: rgba(0,255,204,0.08);
#   border: 1px solid rgba(0,255,204,0.4);
#   border-radius: 10px;
#   margin: 8px 0;
#   padding: 8px 14px;
#   cursor: pointer;
#   transition: all 0.2s ease;
# }
#
# .algo-tsp-box label:hover {
#   background: rgba(0,255,204,0.2);
#   box-shadow: 0 0 8px rgba(0,255,204,0.5);
# }
#
# .algo-tsp-box input[type="radio"] {
#   accent-color: #00ffcc;
#   float: right;
#   transform: scale(1.3);
# }
# </style>
#
# <div class="algo-tsp-box">
#   <h2>🧭 7️⃣ TSP Heuristic</h2>
#
#   <p><strong>Scenario:</strong> A city wants to design bus routes covering all neighborhoods.
#   There are hundreds of possible routes, and finding the perfect shortest set is too complex.</p>
#
#   <p><b>Select the approach the city could use:</b></p>
#
#   <label>A. Check all 120 possible routes <input type="radio" name="tsp"></label>
#   <label>B. Always go to nearest unvisited city <input type="radio" name="tsp"></label>
#   <label>C. Randomly choose cities and hope for shortest path <input type="radio" name="tsp"></label>
#   <label>D. List routes alphabetically <input type="radio" name="tsp"></label>
# </div>

# %%
Type the letter corresponding to the correct answer choice below:

# %% [markdown]
# <style>
# /* 📈 Efficiency Ranking Styling */
# .algo-efficiency-box {
#   background: linear-gradient(135deg, #090a0f, #0b0c0f, #0e0e13);
#   color: #e9ecf3;
#   padding: 25px;
#   border-radius: 16px;
#   max-width: 900px;
#   margin: 30px auto;
#   font-family: "Segoe UI", system-ui, sans-serif;
#   box-shadow: 0 0 25px rgba(0, 255, 170, 0.25);
#   border: 1px solid rgba(0, 255, 170, 0.4);
#   line-height: 1.7em;
# }
#
# .algo-efficiency-box h2 {
#   color: #00ffcc;
#   text-shadow: 0 0 12px rgba(0,255,204,0.9);
#   margin-bottom: 18px;
#   font-weight: 600;
# }
#
# /* Table styling */
# .algo-efficiency-table {
#   width: 100%;
#   border-collapse: collapse;
#   border-radius: 10px;
#   overflow: hidden;
#   box-shadow: 0 0 10px rgba(0,255,204,0.15);
# }
#
# .algo-efficiency-table th, .algo-efficiency-table td {
#   padding: 10px 14px;
#   text-align: center;
# }
#
# .algo-efficiency-table th {
#   background: rgba(0,255,204,0.1);
#   color: #00ffcc;
#   font-weight: 600;
#   border-bottom: 2px solid rgba(0,255,204,0.3);
#   text-shadow: 0 0 6px rgba(0,255,204,0.7);
# }
#
# .algo-efficiency-table tr:nth-child(even) {
#   background: rgba(255,255,255,0.03);
# }
#
# .algo-efficiency-table td {
#   border-bottom: 1px solid rgba(255,255,255,0.08);
# }
#
# /* Optional color hints for growth rate perception */
# .algo-efficiency-table td:nth-child(2) { color: #00e676; } /* linear */
# .algo-efficiency-table td:nth-child(3) { color: #ffeb3b; } /* quadratic */
# .algo-efficiency-table td:nth-child(4) { color: #ff7043; } /* exponential */
#
# .algo-efficiency-legend {
#   margin-top: 12px;
#   font-size: 0.95em;
#   color: #aaa;
#   text-align: center;
# }
#
# .algo-efficiency-legend span {
#   display: inline-block;
#   margin: 0 10px;
# }
# </style>
#
# <div class="algo-efficiency-box">
#   <h2>📈 8️⃣ Efficiency Ranking</h2>
#
#   <table class="algo-efficiency-table">
#     <thead>
#       <tr>
#         <th>n</th>
#         <th>Algorithm P</th>
#         <th>Algorithm Q</th>
#         <th>Algorithm R</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr><td>1</td><td>1</td><td>1</td><td>2</td></tr>
#       <tr><td>2</td><td>2</td><td>4</td><td>4</td></tr>
#       <tr><td>3</td><td>3</td><td>9</td><td>8</td></tr>
#       <tr><td>4</td><td>4</td><td>16</td><td>16</td></tr>
#       <tr><td>5</td><td>5</td><td>25</td><td>32</td></tr>
#     </tbody>
#   </table>
#
#   <div class="algo-efficiency-legend">
#     <span style="color:#00e676;">🟢 Linear (P)</span>
#     <span style="color:#ffeb3b;">🟡 Quadratic (Q)</span>
#     <span style="color:#ff7043;">🟠 Exponential (R)</span>
#   </div>
# </div>

# %%
Rank each algorithm from most -> least efficent below:
