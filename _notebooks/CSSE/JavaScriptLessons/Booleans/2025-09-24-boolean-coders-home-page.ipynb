# %%
---
title: Calculator Lesson 
comments: true
layout: post
permalink: /javascript/calculator
description: Calculator Lesson
author: The Coders!
---

# %% [markdown]
# ## 🧮 Calculator Lesson
# > *Learn how to use **Booleans** and **Arrays** in a Calculator! Master the fundamentals of programming logic.*
#
# <div style="text-align: center; margin: 20px 0;">
#   <img src="https://media.giphy.com/media/3o7btPCcdNniyf0ArS/giphy.gif" alt="Calculator" width="300" style="border-radius: 10px;">
# </div>
#
# ---
# **Steps:**
# - Understand Arrays
# - Understand Booleans
# - Hacks
# - Homework
#
# ---
#
# ## 📊 1️⃣ Arrays
# ### *What is an **ARRAY**?*
#
# Arrays are ordered collections of data that can store multiple values in a single variable. Think of them as containers that hold related information!
#
# **Key Features:**
# - 📦 Store multiple values
# - 🔢 Access elements by index
# - 📏 Dynamic size
# - 🔄 Iterable structure
#
# <style>
# .enhanced-button {
#   background: linear-gradient(135deg, #4ade80, #22c55e);
#   color: black !important;
#   padding: 15px 30px;
#   border: none;
#   border-radius: 12px;
#   cursor: pointer;
#   font-weight: bold;
#   font-size: 16px;
#   box-shadow: 0 4px 15px rgba(74, 222, 128, 0.3);
#   transition: all 0.3s ease;
#   text-decoration: none !important;
#   display: inline-block;
#   position: relative;
#   overflow: hidden;
# }
#
# .enhanced-button:hover {
#   transform: translateY(-3px) scale(1.05);
#   box-shadow: 0 8px 25px rgba(74, 222, 128, 0.5);
#   background: linear-gradient(135deg, #22c55e, #16a34a);
#   color: black !important;
#   text-decoration: none !important;
# }
#
# .enhanced-button:active {
#   transform: translateY(-1px) scale(1.02);
#   box-shadow: 0 5px 15px rgba(74, 222, 128, 0.4);
# }
#
# .enhanced-button:visited {
#   color: black !important;
# }
#
# .enhanced-button:link {
#   color: black !important;
# }
#
# .enhanced-button::before {
#   content: '';
#   position: absolute;
#   top: 0;
#   left: -100%;
#   width: 100%;
#   height: 100%;
#   background: linear-gradient(90deg, transparent, rgba(255,255,255,0.3), transparent);
#   transition: left 0.6s ease;
# }
#
# .enhanced-button:hover::before {
#   left: 100%;
# }
#
# .enhanced-button-green {
#   background: linear-gradient(135deg, #34d399, #10b981);
#   box-shadow: 0 4px 15px rgba(52, 211, 153, 0.3);
#   color: black !important;
# }
#
# .enhanced-button-green:hover {
#   background: linear-gradient(135deg, #10b981, #059669);
#   box-shadow: 0 8px 25px rgba(52, 211, 153, 0.5);
#   color: black !important;
# }
#
# .enhanced-button-green:visited {
#   color: black !important;
# }
#
# .enhanced-button-green:link {
#   color: black !important;
# }
# </style>
#
# <div align="center" style="margin: 20px 0;">
#   <a href="{{site.baseurl}}/Group-projects/array" target="_blank" class="enhanced-button">
#     📚 Array Definition + Examples
#   </a>
#   <a href="{{site.baseurl}}/Group-projects/array-hack" target="_blank" class="enhanced-button enhanced-button-green" style="margin-left: 15px;">
#     🔧 Array Hack Challenge
#   </a>
# </div>
#
# ---
#
# ## 🔤 2️⃣ Booleans
# ### *What are **BOOLEANS**?*
#
# Booleans are the simplest data type - they can only be `true` or `false`. They're the foundation of all logical operations in programming!
#
# **Core Concepts:**
# - ✅ `true` - represents a positive condition
# - ❌ `false` - represents a negative condition
# - 🧠 Used in decision making
# - ⚡ Powers conditional statements
#
# <style>
# .enhanced-button-blue {
#   background: linear-gradient(135deg, #60a5fa, #3b82f6);
#   color: black !important;
#   padding: 15px 30px;
#   border: none;
#   border-radius: 12px;
#   cursor: pointer;
#   font-weight: bold;
#   font-size: 16px;
#   box-shadow: 0 4px 15px rgba(96, 165, 250, 0.3);
#   transition: all 0.3s ease;
#   text-decoration: none !important;
#   display: inline-block;
#   position: relative;
#   overflow: hidden;
# }
#
# .enhanced-button-blue:hover {
#   transform: translateY(-3px) scale(1.05);
#   box-shadow: 0 8px 25px rgba(96, 165, 250, 0.5);
#   background: linear-gradient(135deg, #3b82f6, #2563eb);
#   color: black !important;
#   text-decoration: none !important;
# }
#
# .enhanced-button-blue:active {
#   transform: translateY(-1px) scale(1.02);
#   box-shadow: 0 5px 15px rgba(96, 165, 250, 0.4);
# }
#
# .enhanced-button-blue:visited {
#   color: black !important;
# }
#
# .enhanced-button-blue:link {
#   color: black !important;
# }
#
# .enhanced-button-blue::before {
#   content: '';
#   position: absolute;
#   top: 0;
#   left: -100%;
#   width: 100%;
#   height: 100%;
#   background: linear-gradient(90deg, transparent, rgba(255,255,255,0.3), transparent);
#   transition: left 0.6s ease;
# }
#
# .enhanced-button-blue:hover::before {
#   left: 100%;
# }
#
# .enhanced-button-blue-dark {
#   background: linear-gradient(135deg, #3b82f6, #2563eb);
#   box-shadow: 0 4px 15px rgba(59, 130, 246, 0.3);
#   color: black !important;
# }
#
# .enhanced-button-blue-dark:hover {
#   background: linear-gradient(135deg, #2563eb, #1d4ed8);
#   box-shadow: 0 8px 25px rgba(59, 130, 246, 0.5);
#   color: black !important;
# }
#
# .enhanced-button-blue-dark:visited {
#   color: black !important;
# }
#
# .enhanced-button-blue-dark:link {
#   color: black !important;
# }
# </style>
#
# <div align="center" style="margin: 20px 0;">
#   <a href="{{site.baseurl}}/javascript/boolean-blog" target="_blank" class="enhanced-button-blue">
#     🧠 Boolean Definition + Examples
#   </a>
#   <a href="{{site.baseurl}}/javascript/boolean-hack" target="_blank" class="enhanced-button-blue enhanced-button-blue-dark" style="margin-left: 15px;">
#     ⚡ Boolean Hack Challenge
#   </a>
# </div>
#
# ---
#
# ## 📝 3️⃣ Homework Assignments
# ### *Ready to take a quick quiz? Click below to put your knowledge to the test!*
#
#
# ## Quick 10 Minute Homework
#
# <style>
# .enhanced-button-yellow {
#   background: linear-gradient(135deg, #facc15, #f59e0b);
#   color: black !important;
#   padding: 15px 30px;
#   border: none;
#   border-radius: 12px;
#   cursor: pointer;
#   font-weight: bold;
#   font-size: 16px;
#   box-shadow: 0 4px 15px rgba(250, 204, 21, 0.3);
#   transition: all 0.3s ease;
#   text-decoration: none !important;
#   display: inline-block;
#   position: relative;
#   overflow: hidden;
# }
#
# .enhanced-button-yellow:hover {
#   transform: translateY(-3px) scale(1.05);
#   box-shadow: 0 8px 25px rgba(250, 204, 21, 0.5);
#   background: linear-gradient(135deg, #f59e0b, #d97706);
#   color: black !important;
#   text-decoration: none !important;
# }
#
# .enhanced-button-yellow:active {
#   transform: translateY(-1px) scale(1.02);
#   box-shadow: 0 5px 15px rgba(250, 204, 21, 0.4);
# }
#
# .enhanced-button-yellow:visited {
#   color: black !important;
# }
#
# .enhanced-button-yellow:link {
#   color: black !important;
# }
#
# .enhanced-button-yellow::before {
#   content: '';
#   position: absolute;
#   top: 0;
#   left: -100%;
#   width: 100%;
#   height: 100%;
#   background: linear-gradient(90deg, transparent, rgba(255,255,255,0.3), transparent);
#   transition: left 0.6s ease;
# }
#
# .enhanced-button-yellow:hover::before {
#   left: 100%;
# }
# </style>
#
# <div align="center" style="margin: 20px 0;">
#   <a href="https://forms.gle/aNAJ45WNaekwYMmh8" target="_blank" class="enhanced-button-yellow">
#     🛠️ Array Logic Homework
#   </a>
# </div>
#
# <div align="center" style="margin: 20px 0;">
#   <a href="{{site.baseurl}}//javascript/boolean-hack" target="_blank" class="enhanced-button-yellow">
#     🧠 Boolean Logic Homework
#   </a>
# </div>
#
# ---
#
# <div style="text-align: center; margin: 30px 0; padding: 20px; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 15px; color: white;">
#   <h3 style="margin: 0; color: white;">🎉 Ready to Build Amazing Things?</h3>
#   <p style="margin: 10px 0; color: white;">You now have the tools to create powerful calculator features using arrays and booleans!</p>
# </div>
