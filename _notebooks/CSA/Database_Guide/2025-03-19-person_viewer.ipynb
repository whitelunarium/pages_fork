# %% [markdown]
# ---
# layout: post
# title: Person View Developer Documentation
# categories: [Toolkit]
# toc: true
# comments: true
# permalink: /toolkit/documentation/person
# author: Beijan Moniza
# ---

# %% [markdown]
# # Person Viewer Developer Documentation
# ## Overview
# This page displays a list of people loaded from a database. It uses:
#
# - Thymeleaf for dynamic HTML generation.
# - Bootstrap for styling.
# - DataTables for table features like sorting, searching, and pagination.
# - JavaScript for checking and updating profile picture links.
#
# ## HTML Structure
# 1. Thymeleaf Fragment
# Defines the body content and removes the outer <th:block> tag when rendering.
#
# <img width="437" alt="Image" src="https://github.com/user-attachments/assets/e4fa89e9-448f-4c9c-aee6-d14597576632" />
#
# 2. Main Container and Header
# Sets up the page title inside a styled Bootstrap container.
#
# <img width="731" alt="Image" src="https://github.com/user-attachments/assets/4ffc97a8-3ff1-45ab-8c4f-9731c1f84d8a" />
#
# 3. Person Viewer Section
# Creates another styled section to hold the main table.
#
# <img width="502" alt="Image" src="https://github.com/user-attachments/assets/172efb21-2588-4c9a-91d5-5e2d858b91bf" />
#
# 4. Person Data Table
# Table Headers
# Sets up the table columns.
#
# <img width="399" alt="Image" src="https://github.com/user-attachments/assets/529866fc-7cac-487f-98a6-0fe5c9abb6ac" />
#
# Table Rows
# Each row displays a person’s data dynamically using Thymeleaf.
#
# <img width="1263" alt="Image" src="https://github.com/user-attachments/assets/695ab2b7-7566-4850-b0b3-6b2900db9f54" />
#
# ## JavaScript Functionality
# 1. DataTables Setup
# Enables sorting, searching, and pagination on the table.
#
# <img width="575" alt="Image" src="https://github.com/user-attachments/assets/554eab09-f303-4cfe-a37e-b2ac56c63308" />
#
# 2. Image Existence Check
# A helper function to check if a GitHub profile image exists.
#
# <img width="254" alt="Image" src="https://github.com/user-attachments/assets/85f8085b-9686-4871-8ebf-6f08890df07e" />
#
# 3. Update Profile Picture Link
# Updates or removes the link to a profile picture depending on if it exists.
#
# <img width="535" alt="Image" src="https://github.com/user-attachments/assets/721722eb-002a-48a3-8511-d4c2d275a7e6" />
#
# 4. On Page Load
# After the page loads, it updates all profile picture links.
#
# <img width="518" alt="Image" src="https://github.com/user-attachments/assets/f6d2ede7-3128-4d11-a804-648c421beb04" />
#
# ## Summary
#
# <img width="941" alt="Image" src="https://github.com/user-attachments/assets/6df23c2c-8a2e-492c-b512-294a9a79affa" />
#
# - The page lists people’s details like ID, UID, Name, Email, Balance, and more.
# - DataTables provides sorting, searching, and pagination.
# - JavaScript checks and updates GitHub profile pictures automatically.
# - Update and Delete buttons allow managing each person's information.
